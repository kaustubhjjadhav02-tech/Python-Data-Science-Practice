# %%
import numpy as np

# %%
age = np.array([24,23,27,29])
age
# Out:
# array([24, 23, 27, 29])

# %%
print(age)
type(age)
# Out:
# [24 23 27 29]
# numpy.ndarray

# %%
age.ndim
# Out:
# 1

# %%
age_1 = np.array([[24],[23],[27],[29]])
age_1
# Out:
# array([[24],
#        [23],
#        [27],
#        [29]])

# %%
age_1.ndim
# Out:
# 2

# %%
data = np.array([[24,170,58],[23,168,52],[27,172,61],[29,156,45]])
data
# Out:
# array([[ 24, 170,  58],
#        [ 23, 168,  52],
#        [ 27, 172,  61],
#        [ 29, 156,  45]])

# %%
data.shape
# Out:
# (4, 3)

# %%
# Rows and Column
data[:,0:1]
# Out:
# array([[24],
#        [23],
#        [27],
#        [29]])

# %%
data[:,1:3]
# Out:
# array([[170,  58],
#        [168,  52],
#        [172,  61],
#        [156,  45]])

# %%
data[1:3,0:1]
# Out:
# array([[23],
#        [27]])

# %%
d = data[:,0:1]
d
# Out:
# array([[24],
#        [23],
#        [27],
#        [29]])

# %%
print("Mean: ",np.mean(d))
# Out:
# Mean:  25.75

# %%
print("Median: ",np.median(d))
# Out:
# Median:  25.5

# %%
print("Mode: ",np.mode(d))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print("Mode: ",np.mode(d))
#
# File ~\Downloads\Anaconda\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
print("Standard Deviation: ",np.std(d))
# Out:
# Standard Deviation:  2.384848003542364

# %%
print("Variance: ",np.var(d))
# Out:
# Variance:  5.6875

# %%
print("Minimum: ",np.min(d))
# Out:
# Minimum:  23

# %%
print("Maximum: ",np.max(d))
# Out:
# Maximum:  29

# %%
np.random.random(10) # print numbers from 0 to 1
# Out:
# array([0.68870708, 0.90170873, 0.83079985, 0.16158686, 0.17036524,
#        0.14434685, 0.55895882, 0.90730029, 0.6063741 , 0.9248878 ])

# %%
np.random.random(5) # print numbers from 0 to 1
# Out:
# array([0.28781611, 0.72830801, 0.29164296, 0.26126   , 0.04206083])

# %%
r1 =np.random.randint(10,40,size = 5)
r1
# Out:
# array([31, 12, 22, 27, 18])

# %%
r1.ndim
# Out:
# 1

# %%
r2 =np.random.randint(10,40,size = (2,5))
r2
# Out:
# array([[25, 26, 32, 19, 31],
#        [14, 27, 39, 37, 24]])

# %%
r2.ndim
# Out:
# 2

# %%
r3 =np.random.randint(10,40,size = (2,2,5))
r3
# Out:
# array([[[21, 14, 24, 25, 35],
#         [18, 20, 32, 23, 11]],
#
#        [[35, 21, 28, 33, 39],
#         [13, 38, 24, 25, 28]]])

# %%
r3.ndim
# Out:
# 3

# %%
lucky_draw = np.random.randint(1000,9999, size = 1)
lucky_draw
# Out:
# array([9325])

# %%
data
# Out:
# array([[ 24, 170,  58],
#        [ 23, 168,  52],
#        [ 27, 172,  61],
#        [ 29, 156,  45]])

# %%
import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#     0    1   2
# 0  24  170  58
# 1  23  168  52
# 2  27  172  61
# 3  29  156  45

# %%
df.columns = ["age","height","weight"]
df
# Out:
#    age  height  weight
# 0   24     170      58
# 1   23     168      52
# 2   27     172      61
# 3   29     156      45

# %%
df.index = ["a","b","c","d"]
df
# Out:
#    age  height  weight
# a   24     170      58
# b   23     168      52
# c   27     172      61
# d   29     156      45

# %%
df.age
# Out:
# a    24
# b    23
# c    27
# d    29
# Name: age, dtype: int32

# %%
a1 = df["age"]
a1
# Out:
# a    24
# b    23
# c    27
# d    29
# Name: age, dtype: int32

# %%
print("Mean: ",a1.mean())
print("Median: ",a1.median())
print("Mode: ",a1.mode())
print("Std: ",a1.std())
print("Var: ",a1.var())
print("Min: ",a1.min())
print("Max: ",a1.max())
# Out:
# Mean:  25.75
# Median:  25.5
# Mode:  0    23
# 1    24
# 2    27
# 3    29
# Name: age, dtype: int32
# Std:  2.753785273643051
# Var:  7.583333333333333
# Min:  23
# Max:  29

# %%
df["age"].describe()
# Out:
# count     4.000000
# mean     25.750000
# std       2.753785
# min      23.000000
# 25%      23.750000
# 50%      25.500000
# 75%      27.500000
# max      29.000000
# Name: age, dtype: float64

# %%
df.describe()
# Out:
#              age      height     weight
# count   4.000000    4.000000   4.000000
# mean   25.750000  166.500000  54.000000
# std     2.753785    7.187953   7.071068
# min    23.000000  156.000000  45.000000
# 25%    23.750000  165.000000  50.250000
# 50%    25.500000  169.000000  55.000000
# 75%    27.500000  170.500000  58.750000
# max    29.000000  172.000000  61.000000
