# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("nyc_weather.csv")
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df.head() # it will fetch top 5 rows
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5    NaN
# 1               10             7               0           3    NaN
# 2               10             8               0           1    NaN
# 3               10             9               0           3    NaN
# 4               10             5               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(3)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5    NaN
# 1               10             7               0           3    NaN
# 2               10             8               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df.tail() # it will fetch bottom 5 rows
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  01-27-2016           41        22        45                 30.03
# 27  01-28-2016           37        20        51                 29.90
# 28  01-29-2016           36        21        50                 29.58
# 29  01-30-2016           34        16        46                 30.01
# 30  01-31-2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10             7               T           3   Rain
# 27               10             5               0           1    NaN
# 28               10             8               0           4    NaN
# 29               10             7               0           0    NaN
# 30               10             5               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.tail(7)
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 24  01-25-2016           34        18        54                 30.25
# 25  01-26-2016           43        29        56                 30.03
# 26  01-27-2016           41        22        45                 30.03
# 27  01-28-2016           37        20        51                 29.90
# 28  01-29-2016           36        21        50                 29.58
# 29  01-30-2016           34        16        46                 30.01
# 30  01-31-2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 24               10             3               0           2    NaN
# 25               10             7               0           2    NaN
# 26               10             7               T           3   Rain
# 27               10             5               0           1    NaN
# ...

# %%
df.shape # fetch rows and columns
# Out:
# (31, 11)

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.903226    3.129032      247.129032
# std           1.939405      2.724639    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.info() # fetch details of dataset, help to find null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     int64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.8+ KB

# %%
df.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             0
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5    NaN
# 1               10             7               0           3    NaN
# 2               10             8               0           1    NaN
# 3               10             9               0           3    NaN
# 4               10             5               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df["Events"].value_counts() # In particular column, how many values are there
# Out:
# Events
# Rain        4
# Snow        3
# Fog-Snow    2
# Name: count, dtype: int64

# %%
# Replace Null / Missing values of Events column
df["Events"].mode() # find mode
# Out:
# 0    Rain
# Name: Events, dtype: object

# %%
df["Events"].fillna(value = df["Events"].mode())
# Out:
# 0         Rain
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df["Events"].fillna(value = df["Events"].mode()[0],inplace = True) # replaced null values by mode()
#df["Events"].fillna(value = "No Event",inplace = True)  # replaced null values by "No Event"
# Out:
# C:\Users\Kaustubh Jadhav\AppData\Local\Temp\ipykernel_19964\504051427.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Events"].fillna(value = df["Events"].mode()[0],inplace = True) # replaced null values by mode()

# %%
df.head(10)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
# 5  01-06-2016           33         4        35                 30.50
# 6  01-07-2016           39        11        33                 30.28
# 7  01-08-2016           39        29        64                 30.20
# 8  01-09-2016           44        38        77                 30.16
# 9  01-10-2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5   Rain
# 1               10             7               0           3   Rain
# ...

# %%
df.isnull().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64

# %%
df1 = pd.read_csv("nyc_weather.csv")
df1
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df1.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             0
# PrecipitationIn          0
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
# df1 = df1.fillna(value="No Events")  --> for entire dataset

df1["Events"] = df1["Events"].fillna(value="No Events")  # --> This is with particular column

# %%
df1
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df.isnull().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64

# %%
# To fetch single column
df["Temperature"].head()
# Out:
# 0    38
# 1    36
# 2    40
# 3    25
# 4    20
# Name: Temperature, dtype: int64

# %%
# To fetch multiple columns
df[["Temperature","Humidity","Events"]].head(10)
# Out:
#    Temperature  Humidity Events
# 0           38        52   Rain
# 1           36        46   Rain
# 2           40        47   Rain
# 3           25        44   Rain
# 4           20        41   Rain
# 5           33        35   Rain
# 6           39        33   Rain
# 7           39        64   Rain
# 8           44        77   Rain
# 9           50        71   Rain

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     int64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                31 non-null     object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.8+ KB

# %%
# Fetching multiple columns with index position
df.columns[[1,3,5]]
# Out:
# Index(['Temperature', 'Humidity', 'VisibilityMiles'], dtype='object')

# %%
df[df.columns[[1,3,5]]]
# Out:
#     Temperature  Humidity  VisibilityMiles
# 0            38        52               10
# 1            36        46               10
# 2            40        47               10
# 3            25        44               10
# 4            20        41               10
# 5            33        35               10
# 6            39        33               10
# 7            39        64               10
# 8            44        77                9
# 9            50        71                4
# 10           33        37               10
# 11           35        53               10
# 12           26        42               10
# 13           30        47               10
# 14           43        62                9
# 15           47        70                8
# 16           36        66                8
# 17           25        53                9
# 18           22        42               10
# 19           32        49               10
# 20           31        45               10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     int64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                31 non-null     object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.8+ KB

# %%
df2 = df.iloc[:,3:8]
df2
# Out:
#     Humidity  Sea Level PressureIn  VisibilityMiles  WindSpeedMPH  \
# 0         52                 30.03               10             8
# 1         46                 30.02               10             7
# 2         47                 29.86               10             8
# 3         44                 30.05               10             9
# 4         41                 30.57               10             5
# 5         35                 30.50               10             4
# 6         33                 30.28               10             2
# 7         64                 30.20               10             4
# 8         77                 30.16                9             8
# 9         71                 29.59                4             7
# 10        37                 29.92               10             7
# 11        53                 29.85               10             6
# 12        42                 29.94               10            10
# ...

# %%
df2.shape
# Out:
# (31, 5)

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
# drop a single column
df.drop(["Events"], axis =1, inplace = True)
# df = df.drop(["Events"], axis =1)

# %%
df
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0   01-01-2016           38        23        52                 30.03
# 1   01-02-2016           36        18        46                 30.02
# 2   01-03-2016           40        21        47                 29.86
# 3   01-04-2016           25         9        44                 30.05
# 4   01-05-2016           20        -3        41                 30.57
# 5   01-06-2016           33         4        35                 30.50
# 6   01-07-2016           39        11        33                 30.28
# 7   01-08-2016           39        29        64                 30.20
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 10  01-11-2016           33         8        37                 29.92
# 11  01-12-2016           35        15        53                 29.85
# ...

# %%
df.shape
# Out:
# (31, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     int64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   WindDirDegrees        31 non-null     int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 2.6+ KB

# %%
# drop a multiple columns
df.drop(["PrecipitationIn","EST"], axis =1, inplace = True)

# %%
df.shape
# Out:
# (31, 8)

# %%
df
# Out:
#     Temperature  DewPoint  Humidity  Sea Level PressureIn  VisibilityMiles  \
# 0            38        23        52                 30.03               10
# 1            36        18        46                 30.02               10
# 2            40        21        47                 29.86               10
# 3            25         9        44                 30.05               10
# 4            20        -3        41                 30.57               10
# 5            33         4        35                 30.50               10
# 6            39        11        33                 30.28               10
# 7            39        29        64                 30.20               10
# 8            44        38        77                 30.16                9
# 9            50        46        71                 29.59                4
# 10           33         8        37                 29.92               10
# ...

# %%
# to drop a single row
df.drop(30)
# Out:
#     Temperature  DewPoint  Humidity  Sea Level PressureIn  VisibilityMiles  \
# 0            38        23        52                 30.03               10
# 1            36        18        46                 30.02               10
# 2            40        21        47                 29.86               10
# 3            25         9        44                 30.05               10
# 4            20        -3        41                 30.57               10
# 5            33         4        35                 30.50               10
# 6            39        11        33                 30.28               10
# 7            39        29        64                 30.20               10
# 8            44        38        77                 30.16                9
# 9            50        46        71                 29.59                4
# 10           33         8        37                 29.92               10
# ...

# %%
df.drop(29, axis = 0)
# Out:
#     Temperature  DewPoint  Humidity  Sea Level PressureIn  VisibilityMiles  \
# 0            38        23        52                 30.03               10
# 1            36        18        46                 30.02               10
# 2            40        21        47                 29.86               10
# 3            25         9        44                 30.05               10
# 4            20        -3        41                 30.57               10
# 5            33         4        35                 30.50               10
# 6            39        11        33                 30.28               10
# 7            39        29        64                 30.20               10
# 8            44        38        77                 30.16                9
# 9            50        46        71                 29.59                4
# 10           33         8        37                 29.92               10
# ...

# %%
# to drop a multiple rows
df.drop(index = [2,4,6,8,10])
# Out:
#     Temperature  DewPoint  Humidity  Sea Level PressureIn  VisibilityMiles  \
# 0            38        23        52                 30.03               10
# 1            36        18        46                 30.02               10
# 3            25         9        44                 30.05               10
# 5            33         4        35                 30.50               10
# 7            39        29        64                 30.20               10
# 9            50        46        71                 29.59                4
# 11           35        15        53                 29.85               10
# 12           26         4        42                 29.94               10
# 13           30        12        47                 29.95               10
# 14           43        31        62                 29.82                9
# 15           47        37        70                 29.52                8
# ...

# %%
df3 = pd.read_csv("nyc_weather.csv")
df3.head()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5    NaN
# 1               10             7               0           3    NaN
# 2               10             8               0           1    NaN
# 3               10             9               0           3    NaN
# 4               10             5               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          31 non-null     int64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 2.8+ KB

# %%
df3.dropna()   # dropping all null values at once of dataset
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 15  01-16-2016           47        37        70                 29.52
# 16  01-17-2016           36        23        66                 29.78
# 17  01-18-2016           25         6        53                 29.83
# 21  01-22-2016           26         6        41                 30.21
# 22  01-23-2016           26        21        78                 29.77
# 23  01-24-2016           28        11        53                 29.92
# 26  01-27-2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9             8               T           8      Rain
# 9                 4             7             1.8           7      Rain
# ...

# %%
df3.head()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  01-01-2016           38        23        52                 30.03
# 1  01-02-2016           36        18        46                 30.02
# 2  01-03-2016           40        21        47                 29.86
# 3  01-04-2016           25         9        44                 30.05
# 4  01-05-2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10             8               0           5    NaN
# 1               10             7               0           3    NaN
# 2               10             8               0           1    NaN
# 3               10             9               0           3    NaN
# 4               10             5               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df3.dropna(subset = ["Events"],inplace = True)

# %%
df3
# Out:
#            EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8   01-09-2016           44        38        77                 30.16
# 9   01-10-2016           50        46        71                 29.59
# 15  01-16-2016           47        37        70                 29.52
# 16  01-17-2016           36        23        66                 29.78
# 17  01-18-2016           25         6        53                 29.83
# 21  01-22-2016           26         6        41                 30.21
# 22  01-23-2016           26        21        78                 29.77
# 23  01-24-2016           28        11        53                 29.92
# 26  01-27-2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 8                 9             8               T           8      Rain
# 9                 4             7             1.8           7      Rain
# ...

# %%
len(df3)
# Out:
# 9

# %%
#pd.read_csv("path")   --> to read data
#To store your output

df3.to_csv("Output.csv")
