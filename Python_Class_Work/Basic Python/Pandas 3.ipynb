# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("market.csv")
df
# Out:
#              Region         Product   Subsidiary  Stores   Sales  Inventory  \
# 0            Africa            Boot  Addis Ababa      12   29761     191821
# 1            Africa    Men's Casual  Addis Ababa       4   67242     118036
# 2            Africa     Men's Dress  Addis Ababa       7   76793     136273
# 3            Africa          Sandal  Addis Ababa      10   62819     204284
# 4            Africa         Slipper  Addis Ababa      14   68641     279795
# ..              ...             ...          ...     ...     ...        ...
# 385  Western Europe          Sandal         Rome       3    1249       4611
# 386  Western Europe         Slipper         Rome      13   42442     132283
# 387  Western Europe      Sport Shoe         Rome      14    9969      74848
# 388  Western Europe  Women's Casual         Rome       2   19964      62256
# 389  Western Europe   Women's Dress         Rome      16  106676     389861
#
#      Returns
# 0        769
# 1       2284
# ...

# %%
df.head()  # To get first 5 rows
# Out:
#    Region       Product   Subsidiary  Stores  Sales  Inventory  Returns
# 0  Africa          Boot  Addis Ababa      12  29761     191821      769
# 1  Africa  Men's Casual  Addis Ababa       4  67242     118036     2284
# 2  Africa   Men's Dress  Addis Ababa       7  76793     136273     2433
# 3  Africa        Sandal  Addis Ababa      10  62819     204284     1861
# 4  Africa       Slipper  Addis Ababa      14  68641     279795     1771

# %%
df.tail() # To get last 5 rows
# Out:
#              Region         Product Subsidiary  Stores   Sales  Inventory  \
# 385  Western Europe          Sandal       Rome       3    1249       4611
# 386  Western Europe         Slipper       Rome      13   42442     132283
# 387  Western Europe      Sport Shoe       Rome      14    9969      74848
# 388  Western Europe  Women's Casual       Rome       2   19964      62256
# 389  Western Europe   Women's Dress       Rome      16  106676     389861
#
#      Returns
# 385       48
# 386     1829
# 387      549
# 388      954
# 389     3160

# %%
df.head(12)  # To get first 12 rows
# Out:
#     Region         Product   Subsidiary  Stores   Sales  Inventory  Returns
# 0   Africa            Boot  Addis Ababa      12   29761     191821      769
# 1   Africa    Men's Casual  Addis Ababa       4   67242     118036     2284
# 2   Africa     Men's Dress  Addis Ababa       7   76793     136273     2433
# 3   Africa          Sandal  Addis Ababa      10   62819     204284     1861
# 4   Africa         Slipper  Addis Ababa      14   68641     279795     1771
# 5   Africa      Sport Shoe  Addis Ababa       4    1690      16634       79
# 6   Africa  Women's Casual  Addis Ababa       2   51541      98641      940
# 7   Africa   Women's Dress  Addis Ababa      12  108942     311017     3233
# 8   Africa            Boot      Algiers      21   21297      73737      710
# 9   Africa    Men's Casual      Algiers       4   63206     100982     2221
# 10  Africa     Men's Dress      Algiers      13  123743     428575     3621
# ...

# %%
df.tail(8) # To get last 8 rows
# Out:
#              Region         Product Subsidiary  Stores   Sales  Inventory  \
# 382  Western Europe            Boot       Rome      23   36244     209271
# 383  Western Europe    Men's Casual       Rome       2   37271      91670
# 384  Western Europe     Men's Dress       Rome       2   28249      69058
# 385  Western Europe          Sandal       Rome       3    1249       4611
# 386  Western Europe         Slipper       Rome      13   42442     132283
# 387  Western Europe      Sport Shoe       Rome      14    9969      74848
# 388  Western Europe  Women's Casual       Rome       2   19964      62256
# 389  Western Europe   Women's Dress       Rome      16  106676     389861
#
#      Returns
# 382     1455
# 383     1761
# 384      651
# 385       48
# 386     1829
# 387      549
# 388      954
# 389     3160

# %%
df.shape # to identify numbers of rows and columns
# Out:
# (390, 7)

# %%
df.info() # to get information about data variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      390 non-null    object
#  1   Product     390 non-null    object
#  2   Subsidiary  390 non-null    object
#  3   Stores      390 non-null    int64
#  4   Sales       390 non-null    int64
#  5   Inventory   390 non-null    int64
#  6   Returns     390 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Region"].value_counts()
# Out:
# Region
# Western Europe               62
# Africa                       56
# South America                54
# Pacific                      45
# United States                40
# Canada                       34
# Central America/Caribbean    31
# Eastern Europe               31
# Middle East                  23
# Asia                         14
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      390 non-null    object
#  1   Product     390 non-null    object
#  2   Subsidiary  390 non-null    object
#  3   Stores      390 non-null    int64
#  4   Sales       390 non-null    int64
#  5   Inventory   390 non-null    int64
#  6   Returns     390 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.5+ KB

# %%
d1 = df.groupby("Region")["Sales"].sum()
d1
# Out:
# Region
# Africa                       2342588
# Asia                          460231
# Canada                       2041054
# Central America/Caribbean    3081641
# Eastern Europe               2394940
# Middle East                  4333062
# Pacific                      2296794
# South America                2434783
# United States                5503986
# Western Europe               4873000
# Name: Sales, dtype: int64

# %%
d2 = d1.sort_values()
d2
# Out:
# Region
# Asia                          460231
# Canada                       2041054
# Pacific                      2296794
# Africa                       2342588
# Eastern Europe               2394940
# South America                2434783
# Central America/Caribbean    3081641
# Middle East                  4333062
# Western Europe               4873000
# United States                5503986
# Name: Sales, dtype: int64

# %%
d3 = d1.sort_values(ascending = False)
d3
# Out:
# Region
# United States                5503986
# Western Europe               4873000
# Middle East                  4333062
# Central America/Caribbean    3081641
# South America                2434783
# Eastern Europe               2394940
# Africa                       2342588
# Pacific                      2296794
# Canada                       2041054
# Asia                          460231
# Name: Sales, dtype: int64

# %%
p1 = d3.plot(kind="bar",color = "g")
p1
# Out:
# <Axes: xlabel='Region'>

# %%
p2 = d3.plot.barh(color = "cyan")
p2
# Out:
# <Axes: ylabel='Region'>

# %%
p3 = d3.plot(kind="pie")
p3
# Out:
# <Axes: ylabel='Sales'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      390 non-null    object
#  1   Product     390 non-null    object
#  2   Subsidiary  390 non-null    object
#  3   Stores      390 non-null    int64
#  4   Sales       390 non-null    int64
#  5   Inventory   390 non-null    int64
#  6   Returns     390 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.5+ KB

# %%
d4 = df.groupby("Product")["Returns"].sum()
d4
# Out:
# Product
# Boot               98622
# Men's Casual      233668
# Men's Dress       147266
# Sandal             38170
# Slipper           188693
# Sport Shoe         25179
# Women's Casual    131394
# Women's Dress     174275
# Name: Returns, dtype: int64

# %%
p4 = d4.plot.pie()
p4
# Out:
# <Axes: ylabel='Returns'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      390 non-null    object
#  1   Product     390 non-null    object
#  2   Subsidiary  390 non-null    object
#  3   Stores      390 non-null    int64
#  4   Sales       390 non-null    int64
#  5   Inventory   390 non-null    int64
#  6   Returns     390 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.5+ KB

# %%
p5 = df.plot(kind="scatter",x="Sales",y="Returns")
p5
# Out:
# <Axes: xlabel='Sales', ylabel='Returns'>

# %%
p6 = df.plot(kind="scatter",x="Sales",y="Inventory")
p6
# Out:
# <Axes: xlabel='Sales', ylabel='Inventory'>

# %%
p6 = df.plot(kind="scatter",x="Sales",y="Inventory")
p6
# Out:
# <Axes: xlabel='Sales', ylabel='Inventory'>

# %%
p5 = df.plot(kind="scatter",x="Sales",y="Stores")
p5
# Out:
# <Axes: xlabel='Sales', ylabel='Stores'>

# %%
p7 = df.plot(kind="hist")
p7
# Out:
# <Axes: ylabel='Frequency'>

# %%
p8 = df["Sales"].plot(kind="hist")
p8
# Out:
# <Axes: ylabel='Frequency'>

# %%
p9 = df.plot(kind="box")
p9
# Out:
# <Axes: >

# %%
p10 = df["Sales"].plot(kind="box",vert=False)
p10
# Out:
# <Axes: >

# %%
df["Sales"].describe()
# Out:
# count       390.000000
# mean      76313.023077
# std       95418.194363
# min         325.000000
# 25%       15124.500000
# 50%       38005.500000
# 75%      104344.750000
# max      502636.000000
# Name: Sales, dtype: float64

# %%
Q1 = np.percentile(df["Sales"],25)
Q1
# Out:
# 15124.5

# %%
Q3 = np.percentile(df["Sales"],75)
Q3
# Out:
# 104344.75

# %%
IQR = Q3 - Q1
IQR
# Out:
# 89220.25

# %%
UW = Q3 + (1.5 * IQR)
UW
# Out:
# 238175.125

# %%
df["Sales"] > UW
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 385    False
# 386    False
# 387    False
# 388    False
# 389    False
# Name: Sales, Length: 390, dtype: bool

# %%
df[df["Sales"] > UW]
# Out:
#                         Region         Product   Subsidiary  Stores   Sales  \
# 16                      Africa    Men's Casual        Cairo      25  360209
# 21                      Africa  Women's Casual        Cairo      14  328474
# 99                      Canada            Boot    Vancouver      31  286497
# 100                     Canada    Men's Casual    Vancouver      25  353361
# 103                     Canada  Women's Casual    Vancouver      20  304106
# 105  Central America/Caribbean     Men's Dress     Kingston      23  270863
# 107  Central America/Caribbean         Slipper     Kingston      37  476638
# 110  Central America/Caribbean   Women's Dress     Kingston      41  375817
# 159             Eastern Europe    Men's Casual       Warsaw      15  304093
# 167                Middle East    Men's Casual    Al-Khobar      24  340201
# 168                Middle East     Men's Dress    Al-Khobar      22  261445
# ...

# %%
len(df[df["Sales"] > UW])
# Out:
# 32

# %%
df[df["Sales"] > UW] = UW
# Out:
# C:\Users\Kaustubh Jadhav\AppData\Local\Temp\ipykernel_13576\3733601385.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '238175.125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[df["Sales"] > UW] = UW
# C:\Users\Kaustubh Jadhav\AppData\Local\Temp\ipykernel_13576\3733601385.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '238175.125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df[df["Sales"] > UW] = UW
# C:\Users\Kaustubh Jadhav\AppData\Local\Temp\ipykernel_13576\3733601385.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '238175.125' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
df["Sales"].describe()
# Out:
# count       390.000000
# mean      68469.697436
# std       72825.238554
# min         325.000000
# 25%       15124.500000
# 50%       38005.500000
# 75%      104344.750000
# max      238175.125000
# Name: Sales, dtype: float64

# %%
p10 = df["Sales"].plot(kind="box",vert=False)
p10
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               Stores          Sales      Inventory        Returns
# count     390.000000     390.000000     390.000000     390.000000
# mean    19552.264103   68469.697436  173157.082051   21268.851282
# std     65446.519456   72825.238554  166956.115507   64957.070257
# min         1.000000     325.000000     374.000000      10.000000
# 25%         3.000000   15124.500000   42640.500000     575.000000
# 50%        10.000000   38005.500000  118149.000000    1407.000000
# 75%        18.750000  104344.750000  238175.125000    3438.500000
# max    238175.125000  238175.125000  865325.000000  238175.125000

# %%
p11 = df.plot(kind="box",vert=False)
p11
# Out:
# <Axes: >

# %%
Q1 = np.percentile(df['Inventory'],25)
Q3 = np.percentile(df['Inventory'],75)
IQR = Q3 - Q1
UW_Inventory = Q3 + (1.5 * IQR)

# %%
Inventory_outlier= df[df['Inventory']>UW_Inventory]
Inventory_outlier
# Out:
#                         Region        Product   Subsidiary  Stores     Sales  \
# 106  Central America/Caribbean         Sandal     Kingston    15.0  200156.0
# 131  Central America/Caribbean        Slipper     San Juan     7.0  217891.0
# 154             Eastern Europe        Slipper       Prague    29.0  128971.0
# 162             Eastern Europe        Slipper       Warsaw    16.0  141878.0
# 185                Middle East        Slipper     Tel Aviv    21.0  208004.0
# 206                    Pacific    Men's Dress      Jakarta    22.0  186631.0
# 224                    Pacific        Slipper       Manila    14.0  171735.0
# 227                    Pacific  Women's Dress       Manila    12.0  229372.0
# 304              United States           Boot  Minneapolis    16.0  111940.0
# 306              United States    Men's Dress  Minneapolis    22.0  235842.0
# 311              United States  Women's Dress  Minneapolis    27.0  224168.0
# ...

# %%
print(df[df['Inventory']>UW_Inventory])
# Out:
#                         Region        Product   Subsidiary  Stores     Sales  \
# 106  Central America/Caribbean         Sandal     Kingston    15.0  200156.0
# 131  Central America/Caribbean        Slipper     San Juan     7.0  217891.0
# 154             Eastern Europe        Slipper       Prague    29.0  128971.0
# 162             Eastern Europe        Slipper       Warsaw    16.0  141878.0
# 185                Middle East        Slipper     Tel Aviv    21.0  208004.0
# 206                    Pacific    Men's Dress      Jakarta    22.0  186631.0
# 224                    Pacific        Slipper       Manila    14.0  171735.0
# 227                    Pacific  Women's Dress       Manila    12.0  229372.0
# 304              United States           Boot  Minneapolis    16.0  111940.0
# 306              United States    Men's Dress  Minneapolis    22.0  235842.0
# 311              United States  Women's Dress  Minneapolis    27.0  224168.0
# ...

# %%
Inventory_outlier= df[df['Inventory']>UW_Inventory] = UW_Inventory
print(df[df['Inventory']>UW_Inventory])
# Out:
# Empty DataFrame
# Columns: [Region, Product, Subsidiary, Stores, Sales, Inventory, Returns]
# Index: []

# %%
df[df['Inventory']>UW_Inventory] = UW_Inventory
df['Inventory'].plot(kind="box",vert=False)
# Out:
# <Axes: >

# %%
df1 = pd.read_csv("market.csv")
df1
# Out:
#              Region         Product   Subsidiary  Stores   Sales  Inventory  \
# 0            Africa            Boot  Addis Ababa      12   29761     191821
# 1            Africa    Men's Casual  Addis Ababa       4   67242     118036
# 2            Africa     Men's Dress  Addis Ababa       7   76793     136273
# 3            Africa          Sandal  Addis Ababa      10   62819     204284
# 4            Africa         Slipper  Addis Ababa      14   68641     279795
# ..              ...             ...          ...     ...     ...        ...
# 385  Western Europe          Sandal         Rome       3    1249       4611
# 386  Western Europe         Slipper         Rome      13   42442     132283
# 387  Western Europe      Sport Shoe         Rome      14    9969      74848
# 388  Western Europe  Women's Casual         Rome       2   19964      62256
# 389  Western Europe   Women's Dress         Rome      16  106676     389861
#
#      Returns
# 0        769
# 1       2284
# ...

# %%
import matplotlib.pyplot as plt
continuous_columns = df1.select_dtypes(include=np.number).columns
for col in continuous_columns:
    df1[col].plot(kind="box", vert=False)
    plt.title(f'Box plot of {col}')
    plt.show()

# %% [raw]
# # ============================================================
# # DATA PREPROCESSING AND FEATURE ENGINEERING IN MACHINE LEARNING
# # Dataset: Adult Income Dataset
# # ============================================================
#
# # ================== Step 1. Import Libraries ==================
# # pandas, numpy - data manipulation
# # matplotlib, seaborn - visualization
# # sklearn - preprocessing, encoding, feature selection, etc.
#
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler
# from sklearn.ensemble import IsolationForest, RandomForestClassifier
# from sklearn.feature_selection import mutual_info_classif
#
# # To suppress warnings for cleaner output
# import warnings
# warnings.filterwarnings("ignore")
#
# # ================== Step 2. Load Dataset ==================
# # Make sure your dataset path is correct
# df = pd.read_csv("adult_with_headers (1).csv", na_values=['?', ' ?'])
#
# print("✅ Dataset Loaded Successfully!")
# print("Shape of dataset:", df.shape)
# print("\nPreview of dataset:")
# print(df.head())
#
# # ================== Step 3. Basic EDA ==================
# print("\nData Information:")
# print(df.info())
#
# print("\nSummary statistics of numerical features:")
# print(df.describe())
#
# print("\nMissing values in each column:")
# print(df.isnull().sum())
#
# # ================== Step 4. Handle Missing Values ==================
# # We impute (fill) missing categorical data with the most frequent category
# # For numerical, median imputation is often robust to outliers
#
# cat_cols = df.select_dtypes(include='object').columns
# num_cols = df.select_dtypes(include=np.number).columns
#
# cat_imputer = SimpleImputer(strategy='most_frequent')
# num_imputer = SimpleImputer(strategy='median')
#
# df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])
# df[num_cols] = num_imputer.fit_transform(df[num_cols])
#
# print("\n✅ Missing values handled successfully!")
#
# # ================== Step 5. Encode Target Variable ==================
# # Target variable = "income" (binary classification)
# df['income'] = df['income'].apply(lambda x: 1 if '>50K' in x else 0)
#
# # ================== Step 6. Encoding Categorical Variables ==================
# # One-Hot Encoding -> for features with < 5 categories (nominal)
# # Label Encoding -> for features with >= 5 categories (high cardinality)
#
# onehot_cols = [col for col in cat_cols if df[col].nunique() < 5]
# label_cols = [col for col in cat_cols if df[col].nunique() >= 5]
#
# # One-Hot Encoding
# df = pd.get_dummies(df, columns=onehot_cols, drop_first=True)
#
# # Label Encoding
# le = LabelEncoder()
# for col in label_cols:
#     df[col] = le.fit_transform(df[col])
#
# print("\n✅ Encoding Completed!")
# print("One-Hot Encoded columns:", onehot_cols)
# print("Label Encoded columns:", label_cols)
#
# # --- Notes ---
# # One-Hot Encoding → expands categories into binary columns (good for tree models, non-ordinal data)
# # Label Encoding → assigns numbers to each category (used when there are many unique categories)
#
# # ================== Step 7. Feature Engineering ==================
# # 1️⃣ Create new feature: 'capital_net' = capital-gain - capital-loss
# df['capital_net'] = df['capital_gain'] - df['capital_loss']
#
# # 2️⃣ Age group bins (categorical)
# df['age_group'] = pd.cut(df['age'],
#                          bins=[0, 25, 45, 65, 120],
#                          labels=['Young', 'Adult', 'Mid_Senior', 'Senior'])
#
# # 3️⃣ Feature: hours_per_age ratio
# df['hours_per_age'] = df['hours_per_week'] / (df['age'] + 1e-6)
#
# # --- Log Transformation ---
# # For skewed features like 'capital_gain', we apply log1p transformation
# df['capital_gain_log'] = np.log1p(df['capital_gain'])
#
# print("\n✅ Feature Engineering Completed!")
# print(df[['capital_net', 'age_group', 'hours_per_age', 'capital_gain_log']].head())
#
# # ================== Step 8. Scaling ==================
# # StandardScaler → mean=0, std=1 (good for algorithms assuming Gaussian distribution)
# # MinMaxScaler → scales values to [0,1] (good for bounded activations like neural nets)
#
# scaler_std = StandardScaler()
# scaler_mm = MinMaxScaler()
#
# num_features = df.select_dtypes(include=np.number).columns.drop('income')
#
# df_std = df.copy()
# df_mm = df.copy()
#
# df_std[num_features] = scaler_std.fit_transform(df_std[num_features])
# df_mm[num_features] = scaler_mm.fit_transform(df_mm[num_features])
#
# print("\n✅ Scaling Done!")
# print("\nStandard Scaled sample:\n", df_std[num_features].head())
# print("\nMinMax Scaled sample:\n", df_mm[num_features].head())
#
# # ================== Step 9. Outlier Detection (Isolation Forest) ==================
# iso = IsolationForest(contamination=0.01, random_state=42)
# outlier_pred = iso.fit_predict(df[num_features])
#
# df['is_outlier'] = np.where(outlier_pred == -1, 1, 0)
# print("\nNumber of detected outliers:", df['is_outlier'].sum())
#
# # ================== Step 10. Feature Importance ==================
# # Using Mutual Information as PPS alternative
# X = df.drop(columns=['income', 'is_outlier'])
# y = df['income']
#
# mi_scores = mutual_info_classif(X, y, random_state=42)
# mi_df = pd.DataFrame({'Feature': X.columns, 'MI_Score': mi_scores})
# mi_df = mi_df.sort_values(by='MI_Score', ascending=False)
#
# print("\nTop 10 important features (Mutual Information):")
# print(mi_df.head(10))
#
# # ================== Step 11. Save Preprocessed Dataset ==================
# df.to_csv("adult_preprocessed.csv", index=False)
# print("\n✅ Final preprocessed dataset saved as 'adult_preprocessed.csv'!")
#
# # ================== Step 12. Visualization (Optional) ==================
# plt.figure(figsize=(8, 4))
# sns.histplot(df['capital_gain'], bins=50, kde=True)
# plt.title("Distribution of Capital Gain (Before Log Transform)")
# plt.show()
#
# plt.figure(figsize=(8, 4))
# sns.histplot(df['capital_gain_log'], bins=50, kde=True)
# plt.title("Distribution of Capital Gain (After Log Transform)")
# plt.show()
